# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
MovieList=["vikeam","Leo","Kaithi","Master"]
print(MovieList)
print(MovieList[2])
print(MovieList[3])
# Out:
# ['vikeam', 'Leo', 'Kaithi', 'Master']
# Kaithi
# Master

# %%
MovieList=["vikeam","Leo","Kaithi","Master"]
MovieList.append("RRR")
print(MovieList)
# Out:
# ['vikeam', 'Leo', 'Kaithi', 'Master', 'RRR']

# %%
MovieList=["vikeam","Leo","Kaithi","Master"]
MovieList.insert(2,"RRR")
print(MovieList)
# Out:
# ['vikeam', 'Leo', 'RRR', 'Kaithi', 'Master']

# %%
MovieList=["vikeam","Leo","Kaithi","Master"]
MovieList.remove("Leo")
print(MovieList)
# Out:
# ['vikeam', 'Kaithi', 'Master']

# %%
MovieList=["vikeam","Leo","Kaithi","Master"]
MovieList.pop()
print(MovieList)
# Out:
# ['vikeam', 'Leo', 'Kaithi']

# %%
MovieList=["vikeam","Leo","Kaithi","Master"]
for x in MovieList: print(x)
# Out:
# vikeam
# Leo
# Kaithi
# Master

# %%
MovieList=["vikeam","Leo","Kaithi","Master"]
print(type(MovieList))
# Out:
# <class 'list'>

# %%
MovieList=["vikram","Leo","Kaithi","Master"]
print(len(MovieList))
# Out:
# 4

# %%
#             0       1       2       3        4
MovieList=["vikram","Leo","Kaithi","Master","Rolex"]
print(MovieList[1:4]) #betn 1 to 4, but (last)4th not consider
# Out:
# ['Leo', 'Kaithi', 'Master']

# %%
#            -5      -4     -3       -2       -1
MovieList=["vikram","Leo","Kaithi","Master","Rolex"]
print(MovieList[-4:-1])
# Out:
# ['Leo', 'Kaithi', 'Master']
