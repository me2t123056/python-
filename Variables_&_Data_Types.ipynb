# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/basic-of-python/Variables_%26_Data_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#A variable is a name used to store a value in a program.

# %%
#single variable declaration
name="Meet"
age=20
hight=5.7
print(name)
print(age)
print(hight)
# Out:
# Meet
# 20
# 5.7

# %%
#multiple variable declaration in one line
name,age,city="Meet",20,"surat"
print(name)
print(age)
print(city)
print(name,age,city)
# Out:
# Meet
# 20
# surat
# Meet 20 surat
