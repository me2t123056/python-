# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filename = "meet_record.txt"

with open(filename, "w", encoding="utf-8") as f:
    f.write("Data Science Learning Record\n")
    f.write("Unit 1 completed\n")

with open(filename, "a", encoding="utf-8") as f:
    f.write("Unit 2 completed\n")

with open(filename, "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# Data Science Learning Record
# Unit 1 completed
# Unit 2 completed
