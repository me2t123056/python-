# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "Data Analytics"
print(text[0])
print(text[0:6])
print(text.lower())
print(text.upper())
print(text.replace("Analytics", "Programming"))
print("Data" in text)
# Out:
# D
# Data A
# data analytics
# DATA ANALYTICS
# Data Programming
# True
