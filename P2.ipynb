# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b = 23, 5
print("Sum:", a + b)
print("Floor division:", a // b)
print("Remainder:", a % b)

score = 81
score += 5
print("Updated score:", score)
print("Passed:", score >= 40 and score <= 100)
# Out:
# Sum: 28
# Floor division: 4
# Remainder: 3
# Updated score: 86
# Passed: True
