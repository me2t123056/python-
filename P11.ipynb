# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
import statistics

values = [12, 24, 36, 48, 60]
print("Square root:", math.sqrt(100))
print("Mean:", statistics.mean(values))
print("Median:", statistics.median(values))
print("Random choice:", random.choice(values))
# Out:
# Square root: 10.0
# Mean: 36
# Median: 36
# Random choice: 12
