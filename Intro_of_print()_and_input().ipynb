# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/basic-of-python/Intro_of_print()_and_input().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# use of print() and input() functions

#print(): for display text and info
print("Hello World")
print("My name is Meet Italiya")

print()
name="meet"
age=20
balance=140000.8956

print(name)
print(age)
print(balance)

print()
print("Name:",name)
print("Age:",age)
print("balance",balance)
# Out:
# Hello World
# My name is Meet Italiya
#
# meet
# 20
# 140000.8956
#
# Name: meet
# Age: 20
# balance 140000.8956

# %%
#input : take input from the user

name=input("Enter your name:")
print(name)


print()
a=int(input("Enter A:"))
b=int(input("Enter B:"))
print(a+b)

print()
price=float(input("Enter final amount:"))
print(price)
# Out:
# Enter your name:meet
# meet
#
# Enter A:10
# Enter B:20
# 30
#
# Enter final amount:14000
# 14000.0

# %%
#practical : Personal Introduction

print("welcome to our side")
name=input("Enter your name:")
clg=input("Enter your University:")
sem=int(input("Enter your semester:"))
cgpa=float(input("Enter your CGPA:"))

print("Hello",name)
print("FROM",clg)
print("now in",sem,"SEM")
print("result",cgpa,"CGPA")
# Out:
# welcome to our side
# Enter your name:MEET
# Enter your University:GTU
# Enter your semester:5
# Enter your CGPA:8.14
# Hello MEET
# FROM GTU
# now in 5 SEM
# result 8.14 CGPA
