# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("For loop:")
for i in range(2, 7):
    print(i, end=" ")

print("\nWhile loop:")
n = 6
while n > 0:
    print(n, end=" ")
    n -= 1
# Out:
# For loop:
# 2 3 4 5 6
# While loop:
# 6 5 4 3 2 1
