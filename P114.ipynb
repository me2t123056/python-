# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P114.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = bytes([70, 71, 72, 73])

with open("data.bin", "wb") as f:
    f.write(data)

with open("data.bin", "rb") as f:
    content = f.read()

print(content)
print(list(content))
# Out:
# b'FGHI'
# [70, 71, 72, 73]
