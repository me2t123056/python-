# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [12, 24, 36]
print(24 in nums)
print(50 not in nums)

a = [3, 4]
b = a
c = [3, 4]
print(a == c)
print(a is b)
print(a is c)

x, y = 6, 2
print("AND:", x & y)
print("OR:", x | y)
print("XOR:", x ^ y)
# Out:
# True
# True
# True
# True
# False
# AND: 2
# OR: 6
# XOR: 4
