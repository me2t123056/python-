# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1, 5):
    for j in range(1, 5):
        if j == 3:
            continue
        if i == 4 and j == 4:
            break
        print(f"({i},{j})", end=" ")
    print()

def future_task():
    pass

print("pass executed without action")
# Out:
# (1,1) (1,2) (1,4)
# (2,1) (2,2) (2,4)
# (3,1) (3,2) (3,4)
# (4,1) (4,2)
# pass executed without action
