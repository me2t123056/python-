# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# main.py
value = 14

def show_scope():
    local_value = 26
    print("Inside function:", value, local_value)

show_scope()
print("Global value:", value)

# mymath.py
# def square(n):
#     return n * n

# main.py
# from mymath import square
# print(square(8))
# Out:
# Total: 1280
# Hello, Meet
