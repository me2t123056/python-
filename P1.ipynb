# %% [markdown]
# <a href="https://colab.research.google.com/github/me2t123056/python-/blob/PBL/P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Meet"
age = 22
height = 1.72
is_student = True

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))

value = "31"
print("Converted value:", int(value))
print("Age next year:", age + 1)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# Converted value: 31
# Age next year: 23
